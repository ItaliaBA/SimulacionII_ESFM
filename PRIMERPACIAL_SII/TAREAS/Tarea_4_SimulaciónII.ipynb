# %%
from random import random
import matplotlib.pyplot as plt

def nor(mu,s):
    suma=0
    l=[]
    for i in range(12):
        suma=suma+random()
        x=mu + s * (suma - 6)
    return x 

l1=[]

for i in range(1000):
    l1.append(nor(180,15))
print(l1, len(l1))

plt.hist(l1, color='green', edgecolor='yellow')
plt.title('HISTOGRAMA')
plt.show()
# Out:
# [164.57724906895527, 201.24522581269406, 205.98564640237765, 169.33520545668867, 188.50633905392138, 209.0491457265486, 193.79941406110373, 184.18627881218347, 183.83816936229064, 185.04295252272627, 181.87668700702977, 183.59611656737613, 171.9496895143799, 184.9603930268547, 158.51706244944023, 190.69944339415233, 168.1819417440197, 186.07848429186404, 188.23675929862114, 181.5602166450499, 180.48480517837982, 180.6751086649185, 162.18869660795326, 183.96945470435233, 218.9118577871284, 143.76165034911256, 178.8216685163911, 164.81800500922816, 203.09128506384175, 179.59376455809468, 212.71981791613777, 146.09418238006464, 187.1795285794891, 165.78444018232435, 173.95026348051468, 168.80403186268404, 191.76561646098864, 154.72417833217185, 176.3730797771025, 197.74904204603325, 190.70557299979848, 167.0555228780276, 185.32541826074623, 212.56512577398144, 163.7307436079943, 173.64396040998972, 187.37269054910536, 170.96184644039323, 166.04844601172553, 181.6648736786941, 158.948643
# ...
