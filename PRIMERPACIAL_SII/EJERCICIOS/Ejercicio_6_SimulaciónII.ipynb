# %% [markdown]
# # **Ejercicio 6**:
#
# Repetir el experimento, utilizando un cuarto de elipse

# %%
import random
import matplotlib.pyplot as plt
N = 1000
def pi_Taylor(n):
  L = []
  m = 0
  for i in range(n):
    x_1 = random.random()
    y_1 = random.random()
    z = ((x_1**2)+(y_1**2))**(1/2)
    if z < 1:
        m = m+1
    pi = 4*(m/(i+1))
    print(i,pi)
    L.append(pi) 
  plt.plot(L, color = "black", markersize=1)
  plt.xlabel("Iteraciones")
  plt.ylabel("Estimación")
  plt.grid()
  plt.show()
pi_Taylor(N)
# Out:
# 0 4.0
# 1 2.0
# 2 1.3333333333333333
# 3 2.0
# 4 2.4
# 5 2.6666666666666665
# 6 2.857142857142857
# 7 2.5
# 8 2.6666666666666665
# 9 2.4
# 10 2.5454545454545454
# 11 2.6666666666666665
# 12 2.769230769230769
# 13 2.5714285714285716
# 14 2.6666666666666665
# 15 2.75
# 16 2.823529411764706
# 17 2.888888888888889
# 18 2.736842105263158
# 19 2.8
# 20 2.857142857142857
# 21 2.909090909090909
# 22 2.782608695652174
# 23 2.6666666666666665
# 24 2.72
# 25 2.769230769230769
# 26 2.6666666666666665
# 27 2.7142857142857144
# 28 2.7586206896551726
# 29 2.8
# 30 2.7096774193548385
# 31 2.625
# 32 2.5454545454545454
# 33 2.4705882352941178
# 34 2.5142857142857142
# 35 2.5555555555555554
# 36 2.4864864864864864
# 37 2.526315789473684
# 38 2.4615384615384617
# 39 2.5
# 40 2.5365853658536586
# 41 2.5714285714285716
# 42 2.604651162790698
# 43 2.6363636363636362
# 44 2.577777777777778
# 45 2.608695652173913
# 46 2.6382978723404253
# 47 2.6666666666666665
# 48 2.693877551020408
# 49 2.72
# ...
